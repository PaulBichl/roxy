# %%
import os

from ultralytics import YOLO

# %%
# Load a pretrained YOLO11 classification model
model = YOLO("yolo11s-cls.pt")  # pretrained model, small size

train_results = model.train(
    data="./dataset/",
    epochs=1000,
    imgsz=640,
)
model.export(format="ncnn", imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.4.37 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.240  Python-3.12.3 torch-2.9.1+cpu CPU (AMD Ryzen 7 7800X3D 8-Core Processor)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=./dataset/, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=1000, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train8, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\isabe\Documents\Programmering\roxy\runs\classify\train8, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: C:\Users\isabe\Documents\Programmering\roxy\scripts\ML\dataset\train... found 573 images in 9 classes
# val: C:\Users\isabe\Documents\Programmering\roxy\scripts\ML\dataset\val... found 148 images in 9 classes
# test: None...
# Overriding model.yaml nc=80 with nc=9
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  10                  -1  1    669449  ultralytics.nn.modules.head.Classify         [512, 9]
# YOLO11s-cls summary: 86 layers, 5,454,537 parameters, 5,454,537 gradients, 12.1 GFLOPs
# Transferred 234/236 items from pretrained weights
# train: Fast image access  (ping: 0.00.0 ms, read: 449.559.5 MB/s, size: 40.3 KB)
# train: Scanning C:\Users\isabe\Documents\Programmering\roxy\scripts\ML\dataset\train... 573 images, 0 corrupt: 100% ━━━━━━━━━━━━ 573/573  0.0s
# val: Fast image access  (ping: 0.10.0 ms, read: 420.697.5 MB/s, size: 39.2 KB)
# val: Scanning C:\Users\isabe\Documents\Programmering\roxy\scripts\ML\dataset\val... 148 images, 0 corrupt: 100% ━━━━━━━━━━━━ 148/148 23.3Kit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000769, momentum=0.9) with parameter groups 39 weight(decay=0.0), 40 weight(decay=0.0005), 40 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to C:\Users\isabe\Documents\Programmering\roxy\runs\classify\train8
# Starting training for 1000 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#      1/1000         0G       1.92         13        640: 100% ━━━━━━━━━━━━ 36/36 2.6s/it 1:332.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.6s2.2ss
#                    all      0.507      0.919
#
#       Epoch    GPU_mem       loss  Instances       Size
#      2/1000         0G      1.276         13        640: 100% ━━━━━━━━━━━━ 36/36 2.6s/it 1:322.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.5s2.1ss
#                    all      0.662      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#      3/1000         0G       1.02         13        640: 100% ━━━━━━━━━━━━ 36/36 2.6s/it 1:322.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.5s2.1ss
#                    all       0.73      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#      4/1000         0G     0.9309         13        640: 100% ━━━━━━━━━━━━ 36/36 2.6s/it 1:322.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.5s2.1ss
#                    all      0.743          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      5/1000         0G     0.9029         13        640: 100% ━━━━━━━━━━━━ 36/36 2.6s/it 1:322.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.5s2.1ss
#                    all      0.615      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#      6/1000         0G     0.8974         13        640: 100% ━━━━━━━━━━━━ 36/36 2.6s/it 1:322.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.5s2.1ss
#                    all       0.73          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      7/1000         0G     0.9208         13        640: 100% ━━━━━━━━━━━━ 36/36 2.6s/it 1:322.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.791          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      8/1000         0G     0.7722         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:312.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.777          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      9/1000         0G     0.6356         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:312.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.709          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     10/1000         0G     0.6389         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:302.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.818      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#     11/1000         0G     0.7225         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:312.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.723      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#     12/1000         0G     0.6462         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:312.3sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.824      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#     13/1000         0G     0.6584         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:312.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all       0.77      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#     14/1000         0G     0.6054         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:312.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.851          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     15/1000         0G     0.6154         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:302.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.831      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#     16/1000         0G     0.5923         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:312.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.791          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     17/1000         0G     0.5616         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:312.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.811      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#     18/1000         0G     0.5744         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:312.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.838      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#     19/1000         0G     0.5075         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:302.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.838      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#     20/1000         0G     0.5057         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:302.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.791          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     21/1000         0G     0.4911         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:302.3sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.858      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#     22/1000         0G      0.455         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:302.3sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.3s2.1ss
#                    all      0.845      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#     23/1000         0G     0.4407         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:302.3sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.858          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     24/1000         0G      0.534         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:302.3sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.3s2.1ss
#                    all      0.764      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#     25/1000         0G     0.5018         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:302.3sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.784      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#     26/1000         0G     0.4466         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:302.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.3s2.1ss
#                    all      0.824      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#     27/1000         0G     0.3635         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:302.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.818      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#     28/1000         0G     0.3584         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:302.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.838          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     29/1000         0G     0.4143         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:302.3sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.3s2.1ss
#                    all      0.865      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#     30/1000         0G     0.4215         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:302.3sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.3s2.1ss
#                    all      0.818      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#     31/1000         0G     0.3765         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:302.3sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.818      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#     32/1000         0G     0.4519         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:302.3sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.784      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#     33/1000         0G     0.4066         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:302.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.845      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#     34/1000         0G     0.3473         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:302.3sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.3s2.1ss
#                    all      0.824      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#     35/1000         0G     0.3602         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:312.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.824      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#     36/1000         0G     0.3213         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:302.3sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.3s2.1ss
#                    all      0.831          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     37/1000         0G     0.3514         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:302.3sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.804          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     38/1000         0G     0.3158         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:302.3sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.838       0.98
#
#       Epoch    GPU_mem       loss  Instances       Size
#     39/1000         0G     0.2977         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:302.3sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.845      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#     40/1000         0G     0.3253         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:302.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.3s2.1ss
#                    all      0.845      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#     41/1000         0G     0.3278         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:302.3sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.824      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#     42/1000         0G     0.3402         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:302.3sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.757      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#     43/1000         0G     0.3119         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:302.3sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.838      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#     44/1000         0G     0.3024         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:302.3sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.858      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#     45/1000         0G     0.2829         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:302.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.851      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#     46/1000         0G     0.2577         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:302.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.3s2.1ss
#                    all      0.811      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#     47/1000         0G     0.3425         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:302.3sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.831      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#     48/1000         0G     0.3188         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:312.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.3s2.1ss
#                    all      0.804      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#     49/1000         0G     0.2338         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:302.3sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.3s2.1ss
#                    all      0
13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:312.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.831      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#    135/1000         0G      0.125         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:322.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.5s2.1ss
#                    all      0.831       0.98
#
#       Epoch    GPU_mem       loss  Instances       Size
#    136/1000         0G     0.1571         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:312.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.5s2.1ss
#                    all      0.831       0.98
#
#       Epoch    GPU_mem       loss  Instances       Size
#    137/1000         0G     0.1235         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:312.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.824      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#    138/1000         0G     0.1472         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:312.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.831      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#    139/1000         0G    0.09668         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:312.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.824      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#    140/1000         0G     0.1346         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:312.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.845      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#    141/1000         0G     0.1139         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:312.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.851      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#    142/1000         0G     0.1033         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:312.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.845      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#    143/1000         0G    0.08465         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:312.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.865      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#    144/1000         0G     0.1193         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:312.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.818       0.98
#
#       Epoch    GPU_mem       loss  Instances       Size
#    145/1000         0G     0.1278         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:312.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.838      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#    146/1000         0G     0.1416         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:312.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.5s2.1ss
#                    all      0.804      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#    147/1000         0G     0.1348         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:312.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.5s2.1ss
#                    all      0.851      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#    148/1000         0G     0.1273         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:312.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.5s2.1ss
#                    all      0.858      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#    149/1000         0G    0.08407         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:322.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.5s2.1ss
#                    all      0.865      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#    150/1000         0G     0.1192         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:312.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.5s2.1ss
#                    all      0.851       0.98
#
#       Epoch    GPU_mem       loss  Instances       Size
#    151/1000         0G    0.08152         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:312.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.845       0.98
#
#       Epoch    GPU_mem       loss  Instances       Size
#    152/1000         0G      0.185         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:312.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.858       0.98
#
#       Epoch    GPU_mem       loss  Instances       Size
#    153/1000         0G     0.1343         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:312.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.851          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#    154/1000         0G    0.08975         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:312.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.851      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#    155/1000         0G    0.09331         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:312.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.5s2.1ss
#                    all      0.845      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#    156/1000         0G     0.1004         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:312.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.872      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#    157/1000         0G    0.08164         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:322.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.5s2.1ss
#                    all      0.858      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#    158/1000         0G    0.07618         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:322.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.5s2.1ss
#                    all      0.872       0.98
#
#       Epoch    GPU_mem       loss  Instances       Size
#    159/1000         0G     0.1212         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:312.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.5s2.1ss
#                    all      0.824      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#    160/1000         0G    0.09942         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:312.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.5s2.1ss
#                    all      0.885       0.98
#
#       Epoch    GPU_mem       loss  Instances       Size
#    161/1000         0G     0.1275         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:322.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.858       0.98
#
#       Epoch    GPU_mem       loss  Instances       Size
#    162/1000         0G      0.103         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:322.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.831       0.98
#
#       Epoch    GPU_mem       loss  Instances       Size
#    163/1000         0G     0.1251         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:322.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.5s2.1ss
#                    all      0.838       0.98
#
#       Epoch    GPU_mem       loss  Instances       Size
#    164/1000         0G     0.1132         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:312.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.5s2.1ss
#                    all      0.851      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#    165/1000         0G     0.1143         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:312.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.811      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#    166/1000         0G    0.09581         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:312.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.5s2.1ss
#                    all      0.851      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#    167/1000         0G     0.1006         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:312.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.5s2.1ss
#                    all      0.851      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#    168/1000         0G     0.1107         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:312.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.5s2.1ss
#                    all      0.858          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#    169/1000         0G      0.152         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:322.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.5s2.1ss
#                    all      0.845      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#    170/1000         0G    0.08631         13        640: 100% ━━━━━━━━━━━━ 36/36 2.6s/it 1:322.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.5s2.1ss
#                    all      0.831      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#    171/1000         0G     0.1109         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:322.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.5s2.1ss
#                    all      0.838      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#    172/1000         0G     0.1105         13        640: 100% ━━━━━━━━━━━━ 36/36 2.6s/it 1:322.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.858      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#    173/1000         0G      0.134         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:312.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.851          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#    174/1000         0G    0.08388         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:312.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.831      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#    175/1000         0G    0.08647         13        640: 100% ━━━━━━━━━━━━ 36/36 2.5s/it 1:312.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s2.1ss
#                    all      0.872      0.993
# EarlyStopping: Training stopped early as no improvement observed in last 100 epochs. Best results observed at epoch 75, best model saved as best.pt.
# To update EarlyStopping(patience=100) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 175 epochs completed in 4.786 hours.
# Optimizer stripped from C:\Users\isabe\Documents\Programmering\roxy\runs\classify\train8\weights\last.pt, 11.1MB
# Optimizer stripped from C:\Users\isabe\Documents\Programmering\roxy\runs\classify\train8\weights\best.pt, 11.1MB
#
# Validating C:\Users\isabe\Documents\Programmering\roxy\runs\classify\train8\weights\best.pt...
# Ultralytics 8.3.240  Python-3.12.3 torch-2.9.1+cpu CPU (AMD Ryzen 7 7800X3D 8-Core Processor)
# YOLO11s-cls summary (fused): 47 layers, 5,445,657 parameters, 0 gradients, 12.0 GFLOPs
# train: C:\Users\isabe\Documents\Programmering\roxy\scripts\ML\dataset\train... found 573 images in 9 classes
# val: C:\Users\isabe\Documents\Programmering\roxy\scripts\ML\dataset\val... found 148 images in 9 classes
# test: None...
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.3s/it 6.4s1.8ss
#                    all      0.878          1
# Speed: 0.0ms preprocess, 36.8ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to C:\Users\isabe\Documents\Programmering\roxy\runs\classify\train8
# Ultralytics 8.3.240  Python-3.12.3 torch-2.9.1+cpu CPU (AMD Ryzen 7 7800X3D 8-Core Processor)
# YOLO11s-cls summary (fused): 47 layers, 5,445,657 parameters, 0 gradients, 12.0 GFLOPs
#
# PyTorch: starting from 'C:\Users\isabe\Documents\Programmering\roxy\runs\classify\train8\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 9) (10.5 MB)
#
# NCNN: starting export with NCNN 1.0.20250916 and PNNX 20260112...
# NCNN: export success  2.3s, saved as 'C:\Users\isabe\Documents\Programmering\roxy\runs\classify\train8\weights\best_ncnn_model' (20.8 MB)
#
# Export complete (2.4s)
# Results saved to C:\Users\isabe\Documents\Programmering\roxy\runs\classify\train8\weights
# Predict:         yolo predict task=classify model=C:\Users\isabe\Documents\Programmering\roxy\runs\classify\train8\weights\best_ncnn_model imgsz=640
# Validate:        yolo val task=classify model=C:\Users\isabe\Documents\Programmering\roxy\runs\classify\train8\weights\best_ncnn_model imgsz=640 data=./dataset/
# Visualize:       https://netron.app
# 'C:\\Users\\isabe\\Documents\\Programmering\\roxy\\runs\\classify\\train8\\weights\\best_ncnn_model'

# %%
# showcase
validation_images_dir = "./test_images_v2"

# Get all image file paths (jpg, png, etc.)
image_paths = os.path.join(validation_images_dir, "*.*")

for image in os.listdir(validation_images_dir):
    if image.endswith((".jpg", ".jpeg", ".png", ".bmp", ".gif")):
        img_path = os.path.join(validation_images_dir, image)
        results = model(img_path)  # Predict on an image
        results[0].show()  # Display results
# Out:
# image 1/1 c:\Users\isabe\Documents\Programmering\roxy\scripts\ML\test_images_v2\motion-10.jpg: 640x640 uncertain_cat 0.53, olivia 0.37, human 0.10, background 0.00, prey 0.00, 35.3ms
# Speed: 2.9ms preprocess, 35.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\isabe\Documents\Programmering\roxy\scripts\ML\test_images_v2\motion-11.jpg: 640x640 olivia 1.00, roxy 0.00, uncertain_cat 0.00, cat_close 0.00, uncertain_background 0.00, 31.9ms
# Speed: 2.6ms preprocess, 31.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\isabe\Documents\Programmering\roxy\scripts\ML\test_images_v2\motion-13.jpg: 640x640 olivia 1.00, uncertain_cat 0.00, cat_far 0.00, prey 0.00, roxy 0.00, 32.4ms
# Speed: 2.7ms preprocess, 32.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\isabe\Documents\Programmering\roxy\scripts\ML\test_images_v2\motion-14.jpg: 640x640 uncertain_cat 0.97, prey 0.01, olivia 0.01, cat_far 0.00, background 0.00, 33.5ms
# Speed: 2.9ms preprocess, 33.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\isabe\Documents\Programmering\roxy\scripts\ML\test_images_v2\motion-15.jpg: 640x640 roxy 0.97, uncertain_background 0.02, uncertain_cat 0.01, olivia 0.00, prey 0.00, 44.3ms
# Speed: 3.1ms preprocess, 44.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\isabe\Documents\Programmering\roxy\scripts\ML\test_images_v2\motion-16.jpg: 640x640 roxy 0.54, olivia 0.40, uncertain_cat 0.06, uncertain_background 0.00, human 0.00, 64.8ms
# Speed: 4.9ms preprocess, 64.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\isabe\Documents\Programmering\roxy\scripts\ML\test_images_v2\motion-17.jpg: 640x640 olivia 1.00, uncertain_cat 0.00, roxy 0.00, human 0.00, uncertain_background 0.00, 145.5ms
# Speed: 21.4ms preprocess, 145.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\isabe\Documents\Programmering\roxy\scripts\ML\test_images_v2\motion-18.jpg: 640x640 roxy 1.00, uncertain_cat 0.00, cat_close 0.00, cat_far 0.00, uncertain_background 0.00, 200.5ms
# Speed: 6.3ms preprocess, 200.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\isabe\Documents\Programmering\roxy\scripts\ML\test_images_v2\motion-19.jpg: 640x640 uncertain_cat 0.96, uncertain_background 0.02, olivia 0.01, roxy 0.00, human 0.00, 117.6ms
# Speed: 3.7ms preprocess, 117.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\isabe\Documents\Programmering\roxy\scripts\ML\test_images_v2\motion-20.jpg: 640x640 roxy 0.54, olivia 0.37, cat_far 0.08, uncertain_cat 0.01, cat_close 0.00, 301.0ms
# Speed: 9.1ms preprocess, 301.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\isabe\Documents\Programmering\roxy\scripts\ML\test_images_v2\motion-21.jpg: 640x640 olivia 1.00, roxy 0.00, prey 0.00, cat_close 0.00, uncertain_cat 0.00, 773.8ms
# Speed: 79.6ms preprocess, 773.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\isabe\Documents\Programmering\roxy\scripts\ML\test_images_v2\motion-24.jpg: 640x640 olivia 0.94, roxy 0.03, prey 0.02, uncertain_background 0.01, human 0.01, 262.2ms
# Speed: 9.3ms preprocess, 262.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\isabe\Documents\Programmering\roxy\scripts\ML\test_images_v2\motion-28.jpg: 640x640 olivia 0.70, uncertain_cat 0.30, roxy 0.00, human 0.00, cat_close 0.00, 193.5ms
# Speed: 19.6ms preprocess, 193.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\isabe\Documents\Programmering\roxy\scripts\ML\test_images_v2\motion-32.jpg: 640x640 uncertain_cat 0.93, human 0.03, olivia 0.02, prey 0.00, cat_far 0.00, 70.4ms
# Speed: 6.7ms preprocess, 70.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
