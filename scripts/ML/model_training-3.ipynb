# %%
import os

from ultralytics import YOLO

# %%
# Load a pretrained YOLO11 classification model
model = YOLO("yolo11s-cls.pt")  # pretrained model, small size

train_results = model.train(
    data="./dataset/",
    epochs=1000,
    imgsz=640,
)
model.export(format="ncnn", imgsz=640)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Load a pretrained YOLO11 model calssification model
# ----> 2 model = YOLO("yolo11n-cls.pt")  # pretrained model switch to yolo11x-csl.pt for training session 2
#       4 train_results = model.train(
#       5     data="./dataset/",
#       6     epochs=1000,
#       7     imgsz=640,
#       8 )
#
# NameError: name 'YOLO' is not defined

# %%
# showcase
validation_images_dir = "./test_images_v2"

# Get all image file paths (jpg, png, etc.)
image_paths = os.path.join(validation_images_dir, "*.*")

for image in os.listdir(validation_images_dir):
    if image.endswith((".jpg", ".jpeg", ".png", ".bmp", ".gif")):
        img_path = os.path.join(validation_images_dir, image)
        results = model(img_path)  # Predict on an image
        results[0].show()  # Display results
# Out:
# image 1/1 c:\Users\isabe\Documents\Programmering\roxy\scripts\ML\test_images_v2\motion-10.jpg: 640x640 uncertain_cat 0.82, background 0.16, cat_far 0.01, human 0.00, roxy 0.00, 24.9ms
# Speed: 2.7ms preprocess, 24.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\isabe\Documents\Programmering\roxy\scripts\ML\test_images_v2\motion-11.jpg: 640x640 roxy 0.59, olivia 0.40, uncertain_cat 0.01, uncertain_background 0.00, human 0.00, 15.5ms
# Speed: 2.3ms preprocess, 15.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\isabe\Documents\Programmering\roxy\scripts\ML\test_images_v2\motion-13.jpg: 640x640 olivia 1.00, cat_far 0.00, uncertain_cat 0.00, prey 0.00, uncertain_background 0.00, 15.2ms
# Speed: 2.5ms preprocess, 15.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\isabe\Documents\Programmering\roxy\scripts\ML\test_images_v2\motion-14.jpg: 640x640 uncertain_cat 0.98, background 0.02, human 0.00, cat_far 0.00, prey 0.00, 15.1ms
# Speed: 2.6ms preprocess, 15.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\isabe\Documents\Programmering\roxy\scripts\ML\test_images_v2\motion-15.jpg: 640x640 roxy 0.95, uncertain_background 0.03, uncertain_cat 0.02, olivia 0.00, background 0.00, 28.4ms
# Speed: 3.1ms preprocess, 28.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\isabe\Documents\Programmering\roxy\scripts\ML\test_images_v2\motion-16.jpg: 640x640 cat_far 0.63, uncertain_cat 0.22, background 0.15, olivia 0.00, human 0.00, 19.3ms
# Speed: 3.1ms preprocess, 19.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\isabe\Documents\Programmering\roxy\scripts\ML\test_images_v2\motion-17.jpg: 640x640 olivia 0.99, uncertain_cat 0.01, roxy 0.00, cat_close 0.00, cat_far 0.00, 38.7ms
# Speed: 3.2ms preprocess, 38.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\isabe\Documents\Programmering\roxy\scripts\ML\test_images_v2\motion-18.jpg: 640x640 roxy 0.97, cat_close 0.03, cat_far 0.00, olivia 0.00, human 0.00, 90.5ms
# Speed: 16.5ms preprocess, 90.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\isabe\Documents\Programmering\roxy\scripts\ML\test_images_v2\motion-19.jpg: 640x640 roxy 0.73, uncertain_cat 0.12, olivia 0.06, uncertain_background 0.04, prey 0.02, 71.3ms
# Speed: 10.2ms preprocess, 71.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\isabe\Documents\Programmering\roxy\scripts\ML\test_images_v2\motion-20.jpg: 640x640 olivia 1.00, cat_far 0.00, roxy 0.00, cat_close 0.00, prey 0.00, 33.9ms
# Speed: 7.7ms preprocess, 33.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\isabe\Documents\Programmering\roxy\scripts\ML\test_images_v2\motion-21.jpg: 640x640 olivia 1.00, roxy 0.00, uncertain_cat 0.00, uncertain_background 0.00, human 0.00, 94.4ms
# Speed: 10.2ms preprocess, 94.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\isabe\Documents\Programmering\roxy\scripts\ML\test_images_v2\motion-24.jpg: 640x640 olivia 0.73, roxy 0.26, prey 0.01, human 0.00, uncertain_background 0.00, 274.9ms
# Speed: 17.4ms preprocess, 274.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\isabe\Documents\Programmering\roxy\scripts\ML\test_images_v2\motion-28.jpg: 640x640 uncertain_cat 0.80, cat_far 0.17, background 0.01, olivia 0.01, uncertain_background 0.00, 79.7ms
# Speed: 60.8ms preprocess, 79.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\isabe\Documents\Programmering\roxy\scripts\ML\test_images_v2\motion-32.jpg: 640x640 uncertain_cat 0.99, cat_far 0.01, human 0.00, background 0.00, prey 0.00, 31.5ms
# Speed: 5.5ms preprocess, 31.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
